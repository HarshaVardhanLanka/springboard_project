# %% [markdown]
# <a href="https://colab.research.google.com/github/HarshaVardhanLanka/springboard_project/blob/main/OpenDeepResearchAgent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install tavily-python

# %%
pip install python-dotenv

# %%
# Import necessary libraries
from tavily import TavilyClient
from google.colab import userdata  # For secure secrets

# Load the API key securely from Colab secrets
api_key = userdata.get('TAVILY')  # If not using secrets, use: api_key = "your-api-key-here" (insecure for sharing)

# Initialize the Tavily client
client = TavilyClient(api_key=api_key)

print("Tavily client initialized successfully!")
# Out:
# Tavily client initialized successfully!

# %%
# Perform a simple search
response = client.search("\nWhat is the current weather in New York?\n", max_results=4)

# Print the results
print(response)
# Out:
# {'query': 'What is the current weather in New York?', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'title': 'Weather in New York', 'url': 'https://www.weatherapi.com/', 'content': "{'location': {'name': 'New York', 'region': 'New York', 'country': 'United States of America', 'lat': 40.7142, 'lon': -74.0064, 'tz_id': 'America/New_York', 'localtime_epoch': 1763729218, 'localtime': '2025-11-21 07:46'}, 'current': {'last_updated_epoch': 1763729100, 'last_updated': '2025-11-21 07:45', 'temp_c': 7.2, 'temp_f': 45.0, 'is_day': 1, 'condition': {'text': 'Overcast', 'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png', 'code': 1009}, 'wind_mph': 4.5, 'wind_kph': 7.2, 'wind_degree': 249, 'wind_dir': 'WSW', 'pressure_mb': 1020.0, 'pressure_in': 30.12, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 74, 'cloud': 100, 'feelslike_c': 5.9, 'feelslike_f': 42.7, 'windchill_c': 4.6, 'windchill_f': 40.2, 'heatindex_c': 4.6, 'heatindex_f': 40.3, 'dewpoint_c': 3.2, 'dewpoint
# ...
